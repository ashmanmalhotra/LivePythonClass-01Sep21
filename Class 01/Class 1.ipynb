# %%
12+45
# Out:
# 57

# %%
45+56*2
# Out:
# 157

# %%
12 + 12
# Out:
# 24

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a = 10.10

# %%
a
# Out:
# 10.1

# %%
b = True

# %%
b
# Out:
# True

# %%
a = "String Value"
b = 'String Value'

# %%
a
# Out:
# 'String Value'

# %%
b
# Out:
# 'String Value'

# %%
type(a)
# Out:
# str

# %%
a = 10
type(a)
# Out:
# int

# %%
a = 10.12
type(a)
# Out:
# float

# %%
a = "New Delhi"
type(a)
# Out:
# str

# %%
a = 10
b = 20
c = 30
a
b
# Out:
# 20

# %%
a = 10
b = 20
c = 30
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(a, b)
# Out:
# 10 20

# %%
print("The value of a: ", a)
# Out:
# The value of a:  10

# %%
a = 10
b = 20
c = 30
print("The value of a: ", a)
print("The value of b: ", b)
print("The value of c: ", c)
# Out:
# The value of a:  10
# The value of b:  20
# The value of c:  30

# %%
input("Enter the Number: ")
# Out:
# Enter the Number: 10
# '10'

# %%
aa = input("Enter the Number: ")
print("You input a number : ", aa)
# Out:
# Enter the Number: 1202
# You input a number :  1202

# %%
aa + aa
# Out:
# '12021202'

# %%
-12
# Out:
# -12

# %%
a = -12

# %%
a
# Out:
# -12

# %%
abs(a)
# Out:
# 12

# %%
ascii('$')
# Out:
# "'$'"

# %%
num = 10

# %%
num
# Out:
# 10

# %%
bin(7)
# Out:
# '0b111'

# %%
oct(7)
# Out:
# '0o7'

# %%
hex(7)
# Out:
# '0x7'

# %%
num = 1202
print("Binary Equivalent: ", bin(num))
print("Octal Equivalent: ", oct(num))
print("Hexadecimal Equivalent: ", hex(num))
# Out:
# Binary Equivalent:  0b10010110010
# Octal Equivalent:  0o2262
# Hexadecimal Equivalent:  0x4b2

# %%
int('0b10010110010', 2)
# Out:
# 1202

# %%
int('0o2262', 8)
# Out:
# 1202

# %%
int('0x4b2', 16)
# Out:
# 1202

# %%
num1 = int('0x4b2', 16)
type(num1)
# Out:
# int

# %%
num1 = hex(1202)
type(num1)
# Out:
# str

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
num = 10
type(num)
# Out:
# int

# %%
num = 10
print(id(num))
print(hex(id(num)))
# Out:
# 140726355437632
# 0x7ffd686d2840

# %%
n1 = 10
n2 = n1
print("value n1: ", n1, " Address of n1: ", id(n1))
print("value n2: ", n2, " Address of n2: ", id(n2))
print()

n2 = 20
print("value n1: ", n1, " Address of n1: ", id(n1))
print("value n2: ", n2, " Address of n2: ", id(n2))
# Out:
# value n1:  10  Address of n1:  140726355437632
# value n2:  10  Address of n2:  140726355437632
#
# value n1:  10  Address of n1:  140726355437632
# value n2:  20  Address of n2:  140726355437952

# %%
n1 = 10202032749327947293492398479823949237497329749723947923794798237492394983298498239423984989823
n1
# Out:
# 10202032749327947293492398479823949237497329749723947923794798237492394983298498239423984989823

# %%
n2 = ...
n2
# Out:
# ...

# %%
n2 = ...
n2 + 10
# Out:
# ...

# %%
n = 102052
res = n ** 1020
print(res)
# Out:
# ...
